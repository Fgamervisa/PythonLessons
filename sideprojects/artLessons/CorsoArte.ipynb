# %%
import pandas as pd
import numpy as np

listaSpesa = {
    "Esercizio" : ["Foglio in quadratini", "Tavola di ellissi", "Cerchi concentrici", "Foglio di reti", "Linee ondulate","Misure a matita","Sketch anatomici", "Volto con griglia", "Sketch natura morta", "Tempo libero"],
    "Link" : [np.nan, "https://drawabox.com/lesson/1/tablesofellipses", np.nan, np.nan, np.nan, "https://www.circolodarti.com/come-si-prendono-misure-per-disegnare-dal-vero/#:~:text=Per%20prendere%20una%20misura%20di,vedi%20la%20foto%20a%20fianco", np.nan, np.nan, np.nan, np.nan],
    "Modulo" : [1,1,1,1,1,2,2,2,2,1],
    "Skill" : [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan],
    "Ore" : [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
}

df = pd.DataFrame(listaSpesa)

df
# Out:
#               Esercizio                                               Link  \
# 0  Foglio in quadratini                                                NaN
# 1     Tavola di ellissi     https://drawabox.com/lesson/1/tablesofellipses
# 2    Cerchi concentrici                                                NaN
# 3        Foglio di reti                                                NaN
# 4        Linee ondulate                                                NaN
# 5       Misure a matita  https://www.circolodarti.com/come-si-prendono-...
# 6      Sketch anatomici                                                NaN
# 7     Volto con griglia                                                NaN
# 8   Sketch natura morta                                                NaN
# 9          Tempo libero                                                NaN
#
#    Modulo  Skill  Ore
# 0       1    NaN  NaN
# 1       1    NaN  NaN
# 2       1    NaN  NaN
# 3       1    NaN  NaN
# 4       1    NaN  NaN
# ...

# %%
import pandas as pd

df = pd.read_excel("Schedule.xlsx")

df
# Out:
#               Esercizio                                               Link  \
# 0  Foglio in quadratini                                                NaN
# 1     Tavola di ellissi     https://drawabox.com/lesson/1/tablesofellipses
# 2    Cerchi concentrici                                                NaN
# 3        Foglio di reti                                                NaN
# 4        Linee ondulate                                                NaN
# 5       Misure a matita  https://www.circolodarti.com/come-si-prendono-...
# 6      Sketch anatomici                                                NaN
# 7     Volto con griglia                                                NaN
# 8   Sketch natura morta                                                NaN
# 9          Tempo libero                                                NaN
#
#    Modulo  Skill  Ore
# 0     1.0    NaN  NaN
# 1     1.0    NaN  NaN
# 2     1.0    NaN  NaN
# 3     1.0    NaN  NaN
# 4     1.0    NaN  NaN
# ...

# %%
modulo = int(input("inserisci il modulo a cui sei arrivato"))
esercizi = []
i = 0
for x in df["Modulo"]:
    if x <= modulo:
        esercizi.append(df[])
        i += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Utente\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 6
#       4 for x in df["Modulo"]:
# ...
